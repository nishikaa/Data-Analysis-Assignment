# %%
import pandas as pd
import sqlite3
import os

# %%
# File paths
user_path = os.path.join('..', 'data', 'USER_TAKEHOME.csv')
transaction_path = os.path.join('..', 'data', 'TRANSACTION_TAKEHOME.csv')
product_path = os.path.join('..', 'data', 'PRODUCTS_TAKEHOME.csv')

# %%
# Output DB path 
db_path = os.path.join('takehome.db')

# %%
# Load CSV files
df_user = pd.read_csv(user_path)
df_transaction = pd.read_csv(transaction_path)
df_product = pd.read_csv(product_path)

# %%
# Clean User Data
df_user['CREATED_DATE'] = pd.to_datetime(df_user['CREATED_DATE'], errors='coerce').dt.date
df_user['BIRTH_DATE'] = pd.to_datetime(df_user['BIRTH_DATE'], errors='coerce').dt.date
df_user.drop_duplicates(inplace=True)

# %%
df_user
# Out:
#                              ID CREATED_DATE  BIRTH_DATE STATE LANGUAGE  \
# 0      5ef3b4f17053ab141787697d   2020-06-24  2000-08-11    CA   es-419
# 1      5ff220d383fcfc12622b96bc   2021-01-03  2001-09-24    PA       en
# 2      6477950aa55bb77a0e27ee10   2023-05-31  1994-10-28    FL   es-419
# 3      658a306e99b40f103b63ccf8   2023-12-26         NaT    NC       en
# 4      653cf5d6a225ea102b7ecdc2   2023-10-28  1972-03-19    PA       en
# ...                         ...          ...         ...   ...      ...
# 99995  61fc06d41febf771966da8fa   2022-02-03  1992-03-16    CA       en
# 99996  6391e7ef90ad5449ec5f782d   2022-12-08  1993-09-23    MO       en
# 99997  637d5efdd6f2a49c49934dcb   2022-11-22  1983-04-19    RI       en
# 99998  5f0de23b05d8a6147dc0cafa   2020-07-14  1995-06-09    DE       en
# 99999  5e7ab436905e9512ff44abc8   2020-03-25  1995-12-15    VA      NaN
#
#        GENDER
# 0      female
# 1      female
# 2      female
# 3         NaN
# 4      female
# ...       ...
# 99995  female
# 99996  female
# 99997  female
# 99998  female
# 99999  female
#
# [100000 rows x 6 columns]

# %%
# Clean Transactions Data
df_transaction.drop_duplicates(inplace=True)
df_transaction['PURCHASE_DATE'] = pd.to_datetime(df_transaction['PURCHASE_DATE'], errors='coerce').dt.date
df_transaction['SCAN_DATE'] = pd.to_datetime(df_transaction['SCAN_DATE'], errors='coerce').dt.date
df_transaction['BARCODE'] = df_transaction['BARCODE'].astype(str)

# %%
df_transaction
# Out:
#                                  RECEIPT_ID PURCHASE_DATE   SCAN_DATE  \
# 0      0000d256-4041-4a3e-adc4-5623fb6e0c99    2024-08-21  2024-08-21
# 1      0001455d-7a92-4a7b-a1d2-c747af1c8fd3    2024-07-20  2024-07-20
# 2      00017e0a-7851-42fb-bfab-0baa96e23586    2024-08-18  2024-08-19
# 3      000239aa-3478-453d-801e-66a82e39c8af    2024-06-18  2024-06-19
# 4      00026b4c-dfe8-49dd-b026-4c2f0fd5c6a1    2024-07-04  2024-07-05
# ...                                     ...           ...         ...
# 49995  b5cd61a9-8033-4913-a5c4-fb3f65e3a321    2024-08-21  2024-08-31
# 49996  e1b2f634-c9ad-4152-b662-4b22efc25862    2024-08-11  2024-08-11
# 49997  b07ef8dd-e444-40a2-819b-f74a3e5f1ae7    2024-07-11  2024-07-11
# 49998  42475141-bef4-4df2-aa37-72577e2512bb    2024-06-18  2024-06-18
# 49999  3a179c4e-46f2-4126-b3d2-3514afc23a3e    2024-08-07  2024-08-07
#
#           STORE_NAME                   USER_ID         BARCODE FINAL_QUANTITY  \
# 0            WALMART  63b73a7f3d310dceeabd4758   15300014978.0           1.00
# 1               ALDI  62c08877baa38d1a1f6c211a             nan           zero
# 2            WALMART  60842f207ac8b7729e472020   78742229751.0           1.00
# 3          FOOD LION  63fcd7cea4f8442c3386b589  783399746536.0           zero
# 4           RANDALLS  6193231ae9b3d75037b0f928   47900501183.0           1.00
# ...              ...                       ...             ...            ...
# 49995         TARGET  6154bcf098f885648de2f299   85239110669.0           2.00
# 49996    STOP & SHOP  60aa809f188b926b2244c974   46100400555.0           1.00
# 49997        WALMART  60bd26e83dc3b13a15c5f4e7  646630019670.0           1.00
# 49998  MARKET BASKET  6169912fac47744405af62b7   41800501519.0           1.00
# 49999        WALMART  64e94d64ca929250373ef6e1  307660745853.0           1.00
#
#       FINAL_SALE
# 0
# 1           1.49
# 2
# 3           3.49
# 4
# ...          ...
# 49995       1.18
# 49996       2.00
# 49997      20.96
# 49998       3.00
# 49999       5.48
#
# [49829 rows x 8 columns]

# %%
# Clean Product Data
df_product.drop_duplicates(inplace=True)
df_product['BARCODE'] = df_product['BARCODE'].astype(str)

# %%
df_product
# Out:
#                CATEGORY_1                                CATEGORY_2  \
# 0       Health & Wellness                             Sexual Health
# 1                  Snacks                             Puffed Snacks
# 2       Health & Wellness                                 Hair Care
# 3       Health & Wellness                                 Oral Care
# 4       Health & Wellness                    Medicines & Treatments
# ...                   ...                                       ...
# 845547  Health & Wellness  Topical Muscle & Joint Relief Treatments
# 845548             Snacks                                   Cookies
# 845549             Snacks                                     Candy
# 845550             Snacks                              Nuts & Seeds
# 845551  Health & Wellness                                 First Aid
#
#                          CATEGORY_3 CATEGORY_4  \
# 0       Conductivity Gels & Lotions        NaN
# 1              Cheese Curls & Puffs        NaN
# 2             Hair Care Accessories        NaN
# 3                        Toothpaste        NaN
# 4                    Essential Oils        NaN
# ...                             ...        ...
# 845547               Braces & Wraps        NaN
# 845548                          NaN        NaN
# 845549             Confection Candy        NaN
# 845550                    Hazelnuts        NaN
# 845551               First Aid Kits        NaN
#
#                                              MANUFACTURER            BRAND  \
# 0                                                     NaN              NaN
# 1                                                     NaN              NaN
# 2                                PLACEHOLDER MANUFACTURER          ELECSOP
# 3                                       COLGATE-PALMOLIVE          COLGATE
# 4       MAPLE HOLISTICS AND HONEYDEW PRODUCTS INTERCHA...  MAPLE HOLISTICS
# ...                                                   ...              ...
# 845547                                                NaN              NaN
# 845548                              TREEHOUSE FOODS, INC.        LOFTHOUSE
# 845549                                HARIBO GMBH & CO KG           HARIBO
# 845550                                     DOUBLE-COLA CO            JUMBO
# 845551                                                 3M          NEXCARE
#
#                BARCODE
# 0       796494407820.0
# 1        23278011028.0
# 2       461817824225.0
# 3        35000466815.0
# 4       806810850459.0
# ...                ...
# 845547  722301569399.0
# 845548   41820818468.0
# 845549  100167154940.0
# 845550   75390755960.0
# 845551  796793337781.0
#
# [845337 rows x 7 columns]

# %%
# Create SQLite connection and export tables
conn = sqlite3.connect(db_path)
cursor = conn.cursor()

# %%
df_user.to_sql('user', conn, if_exists='replace', index=False)
df_transaction.to_sql('transaction', conn, if_exists='replace', index=False)
df_product.to_sql('product', conn, if_exists='replace', index=False)
print(f"✅ Tables created successfully in {db_path}")
# Out:
# ✅ Tables created successfully in takehome.db
